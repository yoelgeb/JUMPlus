# %% [markdown]
# # Data Analytics  Notebook 1
# ## By: Jesse, Sumana, Adriel

# %%
import numpy as np
import pandas as pd
import sqlite3

# %% [markdown]
# ### Super Store Data

# %%
conn = sqlite3.connect('superstore.db') 
          
sql_query = pd.read_sql_query ('''
                               SELECT
                               *
                               FROM superstore
                               ''', conn)

df = pd.DataFrame(sql_query)
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 0          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 2          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 3          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9988    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9989    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9990    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer_ID     Customer_Name    Segment        Country             City  \
# ...

# %%
sales = df["Sales"]
city = df["City"]
row_id = df["Row_ID"]
order_id = df["Order_ID"]
ship_mode = df["Ship_Mode"]
cust_id = df["Customer_ID"]
segment = df["Segment"]
country = df["Country"]
city = df["City"]
state = df["State"]
postal_cd = df["Postal_Code"]
region = df["Region"]
prod_id = df["Product_ID"]
cat = df["Category"]
sub_cat = df["Sub_Category"]
quant = df["Quantity"]
discount = df["Discount"]
profit = df["Profit"]

# %%
df.head(5)
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 2       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 3       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 2   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
#   Postal_Code  Region       Product_ID         Category Sub_Category  \
# ...

# %% [markdown]
# # Data Groups

# %% [markdown]
# - Products Sold
# - Unique Cities
# - Unique Customers
# - Unique Products
# - Unique Categories
# - Ship Mode counts
# - Unique Order Dates / Count
# - Unique Ship Dates / Count

# %%
reg_count = df['Region'].value_counts()
reg_count
# Out:
# West       3203
# East       2848
# Central    2323
# South      1619
# Name: Region, dtype: int64

# %%
prod_sold_per_region = df.groupby('Region')['Product_ID'].nunique()
prod_sold_per_region
# Out:
# Region
# Central    1310
# East       1422
# South      1057
# West       1509
# Name: Product_ID, dtype: int64

# %%
unique_cities = df['City'].value_counts().count()
unique_states = df['State'].value_counts().count()
unique_customers = df['Customer_ID'].value_counts().count()
unique_products = df['Product_ID'].value_counts().count()

unique_cities
# Out:
# 531

# %%
ship_mode_count = df['Ship_Mode'].value_counts()
ship_date_count = df['Ship_Date'].value_counts()
order_date_count = df['Order_Date'].value_counts()
cat_count = df['Category'].value_counts()
reg_count = df['Region'].value_counts()
sub_cat_count = df['Sub_Category'].value_counts()

ship_mode_count
# Out:
# Standard Class    5968
# Second Class      1944
# First Class       1538
# Same Day           543
# Name: Ship_Mode, dtype: int64

# %%
prod_sold_per_city = df.groupby('City')['Product_ID'].nunique()
prod_sold_per_state = df.groupby('State')['Product_ID'].nunique()
prod_sold_per_region = df.groupby('Region')['Product_ID'].nunique()

prod_sold_per_state
# Out:
# State
# Alabama                   61
# Arizona                  206
# Arkansas                  57
# California              1204
# Colorado                 171
# Connecticut               81
# Delaware                  95
# District of Columbia      10
# Florida                  345
# Georgia                  175
# Idaho                     21
# Illinois                 435
# Indiana                  142
# Iowa                      30
# Kansas                    24
# Kentucky                 131
# Louisiana                 42
# Maine                      8
# Maryland                 103
# Massachusetts            134
# Michigan                 236
# Minnesota                 86
# Mississippi               52
# Missouri                  66
# Montana                   15
# Nebraska                  38
# Nevada                    38
# New Hampshire             27
# New Jersey               129
# New Mexico                36
# New York                 828
# North Carolina           229
# ...
