# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# Read your cleaned csv which you did in phase 1

# %%
data = pd.read_csv('Video_Games_Sales_cleaned.csv')

# %% [markdown]
#  Shape the data

# %%
print(f'{data.shape[0]} rows')
print(f'{data.shape[1]} columns')
# Out:
# 1313 rows
# 16 columns

# %% [markdown]
# Show first five records

# %%
data.head(5)
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher
# 0             Wii Sports      Wii             2006    Sports  Nintendo  \
# 1         Mario Kart Wii      Wii             2008    Racing  Nintendo
# 2      Wii Sports Resort      Wii             2009    Sports  Nintendo
# 3  New Super Mario Bros.       DS             2006  Platform  Nintendo
# 4               Wii Play      Wii             2006      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score
# 0     41.36     28.96      3.77         8.45         82.53           7.6  \
# 1     15.68     12.76      3.79         3.29         35.52           8.2
# 2     15.61     10.93      3.28         2.95         32.77           8.0
# 3     11.28      9.14      6.50         2.88         29.80           8.9
# 4     13.96      9.18      2.93         2.84         28.92           5.8
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# Describe the data

# %%
data.describe()
# Out:
#        Year_of_Release     NA_Sales     EU_Sales     JP_Sales  Other_Sales
# count      1313.000000  1313.000000  1313.000000  1313.000000  1313.000000  \
# mean       2007.493526     1.385575     0.890975     0.239733     0.312917
# std           4.402760     1.883475     1.371942     0.609561     0.554610
# min        1994.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2004.000000     0.600000     0.340000     0.000000     0.110000
# 50%        2008.000000     0.930000     0.540000     0.020000     0.180000
# 75%        2011.000000     1.550000     1.010000     0.150000     0.320000
# max        2016.000000    41.360000    28.960000     6.500000    10.570000
#
#        Global_Sales  Critic_Score  Critic_Count   User_Score    User_Count
# count   1313.000000   1313.000000   1313.000000  1313.000000   1313.000000
# mean       2.828995      7.946915     43.018279     7.585834    469.365575
# ...

# %% [markdown]
# Group the sales data of each region on Year_of_Release and plot the same

# %%
sales_year = data.groupby('Year_of_Release').sum()[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sort_index()

sales_year_max = sales_year[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].max(axis=1)

sales_year.plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Year_of_Release'>

# %% [markdown]
# Group North American, Japan, European & Other region sales data as per Genre and plot it

# %%
genre_data = data.groupby('Genre').sum()[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sort_index()
genre_data
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Genre
# Action          392.06    274.32     44.97       108.19
# Adventure        15.50     12.00      3.58         4.01
# Fighting         82.70     38.98     17.55        16.77
# Misc            165.00     96.96     29.63        30.96
# Platform        138.69     85.69     38.18        24.22
# Puzzle           22.39     19.91     12.20         4.67
# Racing          157.09    119.28     25.54        44.48
# Role-Playing    143.20     83.52     81.04        27.02
# Shooter         345.53    197.05     14.12        67.92
# Simulation       55.96     46.81     18.39        10.43
# Sports          289.02    186.08     28.12        70.02
# Strategy         12.12      9.25      1.45         2.17

# %%
ax = genre_data.plot(kind='bar', rot=55)
ax.set_ylabel('Total Numbers')
ax.set_xlabel('Genre Category')
# Out:
# Text(0.5, 0, 'Genre Category')

# %% [markdown]
# Group North American, Japan, European & Other region sales data as per Platform and plot it

# %%
platform_data = data.groupby('Platform').sum()[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sort_index()
platform_data
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Platform
# 3DS          30.09     22.89     23.10         4.99
# DC            1.54      0.29      0.38         0.06
# DS          108.50     84.30     68.47        23.05
# GBA          42.88     18.98     11.16         2.67
# GC           49.61     15.63     14.96         2.43
# PC           45.19     50.77      0.17         8.56
# PS           74.76     52.21     33.09         8.98
# PS2         331.32    175.92     50.36       104.70
# PS3         235.40    208.88     31.72        85.83
# PS4          68.33     93.19      6.43        31.09
# PSP          33.87     28.65     12.66        17.57
# PSV           2.48      2.41      0.66         1.14
# Wii         265.37    175.57     46.42        49.18
# WiiU         19.96     13.02      8.71         3.10
# X360        392.50    175.49      5.68        55.92
# XB           60.26     20.11      0.56         2.77
# XOne         57.20     31.54      0.24         8.82

# %%
ax = platform_data.plot(kind='bar', rot=55)
ax.set_xlabel('Platform Genre')
# Out:
# Text(0.5, 0, 'Platform Genre')

# %% [markdown]
# Plot the Sales in all regions as per Platform , you need to create a boxplot for that which will show the distribution of sales as per platform

# %%
data[['NA_Sales', 'Platform']].boxplot(by='Platform')
# Out:
# <AxesSubplot: title={'center': 'NA_Sales'}, xlabel='[Platform]'>

# %%
data[['EU_Sales', 'Platform']].boxplot(by='Platform')
# Out:
# <AxesSubplot: title={'center': 'EU_Sales'}, xlabel='[Platform]'>

# %%
data[['JP_Sales', 'Platform']].boxplot(by='Platform')
# Out:
# <AxesSubplot: title={'center': 'JP_Sales'}, xlabel='[Platform]'>

# %%
data[['Other_Sales', 'Platform']].boxplot(by='Platform')
# Out:
# <AxesSubplot: title={'center': 'Other_Sales'}, xlabel='[Platform]'>

# %% [markdown]
# Find out which Genre games are sold in highest numbers (create a countplot of seaborn which could do that)

# %%
genre_sorted = data.sort_values(by=['Genre'])
sns.countplot(y=genre_sorted['Genre'])
# Out:
# <AxesSubplot: xlabel='count', ylabel='Genre'>

# %% [markdown]
# Try to find out global sales as per Genre

# %%
global_genre = data.groupby('Genre').sum().reset_index()[['Genre', 'Global_Sales']]
global_genre
# Out:
#            Genre  Global_Sales
# 0         Action        819.51
# 1      Adventure         35.06
# 2       Fighting        156.01
# 3           Misc        322.52
# 4       Platform        286.77
# 5         Puzzle         59.17
# 6         Racing        346.39
# 7   Role-Playing        334.64
# 8        Shooter        624.51
# 9     Simulation        131.61
# 10        Sports        573.26
# 11      Strategy         25.02

# %%
sns.barplot(y=global_genre['Genre'], x=global_genre['Global_Sales'])
# Out:
# <AxesSubplot: xlabel='Global_Sales', ylabel='Genre'>
